# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %%
def countWords(files):
    # SparkSession is the entry point to Spark APIs
    spark = SparkSession.builder.master("spark://spark-master:7077").getOrCreate()

    # Read the text files. The content of each file is broken into lines automatically.
    df = spark.read.text(files)

    # Filter out empty lines.
    line = df.filter(df.value != '')

    # Split each line into words, and name the resulting column 'words'
    words = line.select(split(line.value, '\s*(?:\s+|[,\.:]\s|\?")\s*', -1).alias('words'))

    # Rotate each row of words and each word becomes its own row.
    word = words.select(explode(words.words).alias('word'))
    # Filter out empty strings.
    word = word.filter(word.word != '')

    # Group the rows by word and calculate the count for each word.
    wordCount = word.groupBy(word.word).count()
    # Sort the rows by count in descending order.
    wordCount = wordCount.sort('count', ascending=False)

    return wordCount.collect()
    
countWords([
    '/data/dag-analysis-inputs/1.txt'
    , '/data/dag-analysis-inputs/2.txt'
    , '/data/dag-analysis-inputs/3.txt'
    , '/data/dag-analysis-inputs/4.txt'
    , '/data/dag-analysis-inputs/5.txt'
])
# Out:
# [Row(word='the', count=142212),
#  Row(word='of', count=131206),
#  Row(word='a', count=96882),
#  Row(word='and', count=76768),
#  Row(word='to', count=74134),
#  Row(word='Spark', count=64270),
#  Row(word='in', count=57432),
#  Row(word='is', count=53362),
#  Row(word='on', count=52984),
#  Row(word='that', count=52394),
#  Row(word='as', count=43528),
#  Row(word='data', count=41622),
#  Row(word='can', count=38842),
#  Row(word='RDD', count=37936),
#  Row(word='be', count=37170),
#  Row(word='an', count=34588),
#  Row(word='RDDs', count=27728),
#  Row(word='for', count=26962),
#  Row(word='programming', count=24848),
#  Row(word='operations', count=24848),
#  Row(word='or', count=24696),
#  Row(word='such', count=21718),
#  Row(word='are', count=20822),
#  Row(word='by', count=20640),
#  Row(word='API', count=20238),
#  Row(word='Scala', count=18824),
#  Row(word='interface', count=18364),
#  Row(word='program', count=17988),
#  Row(word='Java', count=17974),
#  Row(word='distributed', count=17372),
#  Row(word='new', count=15146),
#  Row(word='map', count=14584),
#  Row(word='function', count=14584),
#  Row(word='also', count=13780),
#  Row(word='streaming', count=13754),
#  Row(word='other', count=12568),
#  Row(word='all', count=12554),
#  Row(word='provides', count=12540),
#  Row(word='Python', count=12540),
#  Row(word='used', count=12498),
#  Row(word='(the', count=12136),
#  Row(word='ones', count=12136),
#  Row(word='available', count=12136),
#  Row(word='JVM', count=12136),
#  Row(word='parallel', count=12122),
#  Row(word='Streaming', count=12092),
#  Row(word='functional', count=11704),
#  Row(word='variables', count=11704),
#  Row(word='languages', count=11704),
#  Row(word='set', count=11648),
#  Row(word='It', count=11462),
#  Row(word='which', count=11426),
#  Row(word='application', count=10640),
#  Row(word='Apache', count=10313),
#  Row(word='cluster', count=10312),
#  Row(word='has', count=10254),
#  Row(word='with', count=9224),
#  Row(word='This', count=9200),
#  Row(word='not', count=8886),
#  Row(word='performs', count=8768),
#  Row(word='scheduling', count=8768),
#  Row(word='mini-batches', count=8748),
#  Row(word='analytics', count=8748),
#  Row(word='its', count=8732),
#  Row(word='single', count=8732),
#  Row(word='but', count=8574),
#  Row(word='project', count=8430),
#  Row(word='any', count=8402),
#  Row(word='it', count=8402),
#  Row(word='their', count=7724),
#  Row(word='reduce', count=7724),
#  Row(word='while', count=7724),
#  Row(word='shared', count=7710),
#  Row(word='abstraction', count=7710),
#  Row(word='A', count=7580),
#  Row(word='In', count=7352),
#  Row(word='input', count=7292),
#  Row(word='foundation', count=7292),
#  Row(word='restricted', count=7292),
#  Row(word='read-only', count=7292),
#  Row(word='These', count=7148),
#  Row(word='some', count=7134),
#  Row(word='example', count=7134),
#  Row(word='needs', count=7134),
#  Row(word='following', count=6716),
#  Row(word='Each', count=6716),
#  Row(word='into', count=6702),
#  Row(word='each', count=6688),
#  Row(word='release', count=6480),
#  Row(word='you', count=6470),
#  Row(word='will', count=6466),
#  Row(word='The', count=6452),
#  Row(word='Hadoop', count=6410),
#  Row(word='exposed', count=6284),
#  Row(word='task', count=6284),
#  Row(word='keeping', count=6284),
#  Row(word='basic', count=6284),
#  Row(word='contain', count=6284),
#  Row(word='common', count=6284),
#  Row(word='then', count=6284),
#  Row(word='passing', count=6270),
#  Row(word='(for', count=6270),
#  Row(word='nodes', count=6270),
#  Row(word='sequence', count=6270),
#  Row(word='type', count=6270),
#  Row(word='through', count=6270),
#  Row(word='run', count=6224),
#  Row(word='should', count=6006),
#  Row(word='operation', count=5852),
#  Row(word='joins', count=5852),
#  Row(word='"lineage"', count=5852),
#  Row(word='two', count=5852),
#  Row(word='"driver"', count=5852),
#  Row(word='broadcast', count=5852),
#  Row(word='fault-tolerance', count=5852),
#  Row(word='I/O', count=5852),
#  Row(word='functionalities', count=5852),
#  Row(word='typical', count=5852),
#  Row(word='park', count=5852),
#  Row(word='reductions', count=5852),
#  Row(word='computes', count=5852),
#  Row(word='(or', count=5852),
#  Row(word='(a', count=5852),
#  Row(word='filter', count=5852),
#  Row(word='words', count=5852),
#  Row(word='cluster.[2]', count=5852),
#  Row(word='mirrors', count=5852),
#  Row(word='takes', count=5852),
#  Row(word='take', count=5852),
#  Row(word='model', count=5852),
#  Row(word='forms', count=5852),
#  Row(word='Julia[17])', count=5852),
#  Row(word='applies', count=5852),
#  Row(word='produced', count=5852),
#  Row(word='RDD-oriented', count=5852),
#  Row(word='execution', count=5852),
#  Row(word='anonymous', count=5852),
#  Row(word='variant', count=5852),
#  Row(word='Besides', count=5852),
#  Row(word='produce', count=5852),
#  Row(word='track', count=5852),
#  Row(word='accumulators', count=5852),
#  Row(word='style.[2]', count=5852),
#  Row(word='frequencies', count=5852),
#  Row(word='overall', count=5852),
#  Row(word='reconstructed', count=5852),
#  Row(word='additional', count=5852),
#  Row(word='reference', count=5852),
#  Row(word='usable', count=5852),
#  Row(word='item', count=5852),
#  Row(word='argument', count=5852),
#  Row(word='dispatching', count=5852),
#  Row(word='lazy;', count=5852),
#  Row(word='RDD-centric', count=5852),
#  Row(word='loss', count=5852),
#  Row(word='pair', count=5852),
#  Row(word='flatMap', count=5852),
#  Row(word='invokes', count=5852),
#  Row(word='centered', count=5852),
#  Row(word='Core', count=5852),
#  Row(word='immutable', count=5852),
#  Row(word='case', count=5852),
#  Row(word='R)', count=5852),
#  Row(word='reduceByKey', count=5852),
#  Row(word='files', count=5852),
#  Row(word='connect', count=5852),
#  Row(word='.NET', count=5852),
#  Row(word='style', count=5852),
#  Row(word='.NET[16]', count=5852),
#  Row(word="function's", count=5852),
#  Row(word='prints', count=5852),
#  Row(word='occurring', count=5852),
#  Row(word='achieved', count=5852),
#  Row(word='objects.', count=5852),
#  Row(word='items)', count=5852),
#  Row(word='so', count=5852),
#  Row(word='schedules', count=5852),
#  Row(word='text', count=5852),
#  Row(word='most', count=5852),
#  Row(word='functional/higher-order', count=5852),
#  Row(word='simple', count=5852),
#  Row(word='imperative', count=5852),
#  Row(word='map)', count=5852),
#  Row(word='non-JVM', count=5852),
#  Row(word='transform', count=5852),
#  Row(word='it)', count=5852),
#  Row(word='support', count=5832),
#  Row(word='event', count=5832),
#  Row(word='we', count=5602),
#  Row(word='where', count=5458),
#  Row(word='use', count=5388),
#  Row(word='from', count=5220),
#  Row(word='programs', count=5184),
#  Row(word='releases', count=5184),
#  Row(word='Structured', count=5006),
#  Row(word='provided', count=4788),
#  Row(word='implementation', count=4774),
#  Row(word='MapReduce', count=4738),
#  Row(word='machine', count=4738),
#  Row(word='storage', count=4738),
#  Row(word='this', count=4630),
#  Row(word='well', count=4602),
#  Row(word='For', count=4594),
#  Row(word='even', count=4464),
#  Row(word='technology', count=4356),
#  Row(word='latency', count=4356),
#  Row(word='2.x', count=4356),
#  Row(word='Dataset', count=4320),
#  Row(word='algorithms', count=4320),
#  Row(word='However', count=4212),
#  Row(word='same', count=4184),
#  Row(word='more', count=3818),
#  Row(word='code', count=3780),
#  Row(word='process', count=3766),
#  Row(word='based', count=3752),
#  Row(word='than', count=3752),
#  Row(word='batch', count=3752),
#  Row(word='uses', count=3752),
#  Row(word='was', count=3744),
#  Row(word='disk', count=3716),
#  Row(word='cost', count=3456),
#  Row(word='-', count=3456),
#  Row(word='there', count=3442),
#  Row(word='have', count=3428),
#  Row(word='How', count=3400),
#  Row(word='fast', count=3334),
#  Row(word='enables', count=3334),
#  Row(word='perform', count=3334),
#  Row(word='called', count=3334),
#  Row(word='launch', count=3298),
#  Row(word='system', count=3298),
#  Row(word='file', count=3298),
#  Row(word='may', count=3168),
#  Row(word='maintained', count=3168),
#  Row(word='these', count=3154),
#  Row(word='after', count=3024),
#  Row(word='APIs', count=3024),
#  Row(word='do', count=2996),
#  Row(word='I', count=2926),
#  Row(word='those', count=2916),
#  Row(word='include', count=2916),
#  Row(word='equal', count=2916),
#  Row(word='convenience', count=2916),
#  Row(word='component', count=2916),
#  Row(word='lambda', count=2916),
#  Row(word='ingests', count=2916),
#  Row(word='duration', count=2916),
#  Row(word='deployed', count=2916),
#  Row(word="Core's", count=2916),
#  Row(word='rather', count=2916),
#  Row(word='Kinesis', count=2916),
#  Row(word='comes', count=2916),
#  Row(word='consume', count=2916),
#  Row(word='cloud.[24]', count=2916),
#  Row(word='mini-batch', count=2916),
#  Row(word='facilitating', count=2916),
#  Row(word='ZeroMQ', count=2916),
#  Row(word='built-in', count=2916),
#  Row(word='architecture.[19][20]', count=2916),
#  Row(word='capability', count=2916),
#  Row(word='Other', count=2916),
#  Row(word='thus', count=2916),
#  Row(word='Kafka', count=2916),
#  Row(word='Twitter', count=2916),
#  Row(word='traditional', count=2916),
#  Row(word='TCP/IP', count=2916),
#  Row(word='Flink.[21]', count=2916),
#  Row(word='separate', count=2916),
#  Row(word='on-premises', count=2916),
#  Row(word='Flume', count=2916),
#  Row(word='penalty', count=2916),
#  Row(word='Storm', count=2916),
#  Row(word='Datasets', count=2916),
#  Row(word='streaming.[23]', count=2916),
#  Row(word='easy', count=2916),
#  Row(word='transformations', count=2916),
#  Row(word='higher-level', count=2916),
#  Row(word='center', count=2916),
#  Row(word='written', count=2916),
#  Row(word='engines', count=2916),
#  Row(word='sockets.[22]', count=2916),
#  Row(word='design', count=2916),
#  Row(word='local', count=2880),
#  Row(word='represent', count=2880),
#  Row(word='File', count=2880),
#  Row(word='iterative', count=2880),
#  Row(word='results', count=2880),
#  Row(word='System', count=2880),
#  Row(word='supports', count=2880),
#  Row(word='over', count=2736),
#  Row(word='released', count=2736),
#  Row(word='standalone', count=2694),
#  Row(word='they', count=2592),
#  Row(word='bug', count=2592),
#  Row(word='users', count=2592),
#  Row(word='when', count=2578),
#  Row(word='possible', count=2304),
#  Row(word='particular', count=2290),
#  Row(word='both', count=2290),
#  Row(word='only', count=2290),
#  Row(word="Spark's", count=2276),
#  Row(word='applications', count=2276),
#  Row(word='YARN', count=2276),
#  Row(word='either', count=2276),
#  Row(word='mode', count=2276),
#  Row(word='compatibility', count=2160),
#  Row(word='months', count=2160),
#  Row(word='point', count=2160),
#  Row(word='about', count=2146),
#  Row(word='does', count=2132),
#  Row(word='been', count=2132),
#  Row(word='no', count=2132),
#  Row(word='versions', count=2118),
#  Row(word='them', count=2118),
#  Row(word='Spark?', count=2104),
#  Row(word='core', count=1872),
#  Row(word='learning', count=1872),
#  Row(word='class', count=1872),
#  Row(word='working', count=1872),
#  Row(word='form', count=1858),
#  Row(word='top', count=1858),
#  Row(word='analysis', count=1858),
#  Row(word='requires', count=1858),
#  Row(word='Mesos', count=1858),
#  Row(word='RDDs.', count=1858),
#  Row(word='scripts', count=1858),
#  Row(word='Amazon', count=1858),
#  Row(word='multiple', count=1858),
#  Row(word='machines', count=1858),
#  Row(word='break', count=1728),
#  Row(word='Release', count=1728),
#  Row(word='Will', count=1728),
#  Row(word='feature', count=1728),
#  Row(word='against', count=1728),
#  Row(word='breaking', count=1728),
#  Row(word='features', count=1728),
#  Row(word='version', count=1728),
#  Row(word='existing', count=1714),
#  Row(word='if', count=1700),
#  Row(word='No', count=1686),
#  Row(word='need', count=1686),
#  Row(word='policy', count=1686),
#  Row(word='engine', count=1672),
#  Row(word='still', count=1440),
#  Row(word='Alluxio', count=1440),
#  Row(word='API.[6][7]', count=1440),
#  Row(word='facilitates', count=1440),
#  Row(word='1.x', count=1440),
#  Row(word='management', count=1440),
#  Row(word='2012', count=1440),
#  Row(word='scenario', count=1440),
#  Row(word='magnitude', count=1440),
#  Row(word='(deliberately)', count=1440),
#  Row(word='variety', count=1440),
#  Row(word='reduction', count=1440),
#  Row(word='Spark.[10]', count=1440),
#  Row(word='Lustre', count=1440),
#  Row(word='repeated', count=1440),
#  Row(word='MapR', count=1440),
#  Row(word='required', count=1440),
#  Row(word='wide', count=1440),
#  Row(word='per', count=1440),
#  Row(word='architectural', count=1440),
#  Row(word='Among', count=1440),
#  Row(word='workflow', count=1440),
#  Row(word='Kubernetes', count=1440),
#  Row(word='CPU', count=1440),
#  Row(word='one', count=1440),
#  Row(word='response', count=1440),
#  Row(word='compared', count=1440),
#  Row(word='purposes', count=1440),
#  Row(word='read', count=1440),
#  Row(word='memory.[8]', count=1440),
#  Row(word='fault-tolerant', count=1440),
#  Row(word='manager', count=1440),
#  Row(word='(MapR-FS),[13]', count=1440),
#  Row(word='graph', count=1440),
#  Row(word='package', count=1440),
#  Row(word='Inside', count=1440),
#  Row(word='visit', count=1440),
#  Row(word='interactive/exploratory', count=1440),
#  Row(word='S3', count=1440),
#  Row(word='resilient', count=1440),
#  Row(word='orders', count=1440),
#  Row(word='times', count=1440),
#  Row(word='instead;', count=1440),
#  Row(word='managed', count=1440),
#  Row(word='implementation.[2][9]', count=1440),
#  Row(word='testing', count=1440),
#  Row(word='dataset', count=1440),
#  Row(word='edges', count=1440),
#  Row(word='usually', count=1440),
#  Row(word='way.[2]', count=1440),
#  Row(word='Swift', count=1440),
#  Row(word='daemons', count=1440),
#  Row(word='developed', count=1440),
#  Row(word='items', count=1440),
#  Row(word='(DAG)', count=1440),
#  Row(word='developing', count=1440),
#  Row(word='deprecated.[4][5]', count=1440),
#  Row(word='across', count=1440),
#  Row(word='formed', count=1440),
#  Row(word='initial', count=1440),
#  Row(word='followed', count=1440),
#  Row(word='manually', count=1440),
#  Row(word='computing', count=1440),
#  Row(word='Dataframe', count=1440),
#  Row(word='directed', count=1440),
#  Row(word='linear', count=1440),
#  Row(word='(native', count=1440),
#  Row(word='Cassandra,[14]', count=1440),
#  Row(word='training', count=1440),
#  Row(word='OpenStack', count=1440),
#  Row(word='executor', count=1440),
#  Row(word='system,[15]', count=1440),
#  Row(word='store', count=1440),
#  Row(word='(HDFS),[12]', count=1440),
#  Row(word='dataflow', count=1440),
#  Row(word='paradigm', count=1440),
#  Row(word='systems', count=1440),
#  Row(word='custom', count=1440),
#  Row(word='several', count=1440),
#  Row(word='Distributed', count=1440),
#  Row(word='solution', count=1440),
#  Row(word='[11]', count=1440),
#  Row(word='including', count=1440),
#  Row(word='reduced', count=1440),
#  Row(word='development', count=1440),
#  Row(word='install', count=1440),
#  Row(word='impetus', count=1440),
#  Row(word='were', count=1440),
#  Row(word='pseudo-distributed', count=1440),
#  Row(word='encouraged[3]', count=1440),
#  Row(word='testing)', count=1440),
#  Row(word='primary', count=1440),
#  Row(word='forces', count=1440),
#  Row(word='structure', count=1440),
#  Row(word='Nodes', count=1440),
#  Row(word='(API)', count=1440),
#  Row(word='acyclic', count=1440),
#  Row(word='implemented', count=1440),
#  Row(word='though', count=1440),
#  Row(word='limitations', count=1440),
#  Row(word='i.e.', count=1440),
#  Row(word='querying', count=1440),
#  Row(word='Kudu', count=1440),
#  Row(word='(RDD)', count=1440),
#  Row(word='offers', count=1440),
#  Row(word='multiset', count=1440),
#  Row(word='database-style', count=1440),
#  Row(word='underlies', count=1440),
#  Row(word='loop', count=1440),
#  Row(word='“experimental”', count=1296),
#  Row(word='happen', count=1296),
#  Row(word='Maintenance', count=1296),
#  Row(word='always', count=1296),
#  Row(word='considered', count=1296),
#  Row(word='fixes', count=1296),
#  Row(word='major', count=1296),
#  Row(word='B', count=1296),
#  Row(word='maximum', count=1296),
#  Row(word='API”', count=1296),
#  Row(word='While', count=1296),
#  Row(word='merged', count=1296),
#  Row(word='window', count=1296),
#  Row(word='marked', count=1296),
#  Row(word='2023', count=1296),
#  Row(word='period', count=1296),
#  Row(word='components', count=1296),
#  Row(word='time', count=1296),
#  Row(word='cases', count=1296),
#  Row(word='might', count=1296),
#  Row(word='last', count=1296),
#  Row(word='how', count=1282),
#  Row(word='longer', count=1282),
#  Row(word='general', count=1282),
#  Row(word='long', count=1282),
#  Row(word='follow', count=1282),
#  Row(word='generally', count=1282),
#  Row(word='Spark’s', count=1268),
#  Row(word='just', count=1268),
#  Row(word='at', count=1268),
#  Row(word='legacy', count=1268),
#  Row(word='processing', count=1268),
#  Row(word='If', count=1254),
#  Row(word='logo', count=1254),
#  Row(word='trademark', count=1254),
#  Row(word='Please', count=1254),
#  Row(word='fit', count=1254),
#  Row(word='memory', count=1254),
#  Row(word='few', count=864),
#  Row(word='“developer', count=864),
#  Row(word='often', count=864),
#  Row(word='typically', count=864),
#  Row(word='Costs', count=864),
#  Row(word='above', count=864),
#  Row(word='compiled', count=864),
#  Row(word='February', count=864),
#  Row(word='occur', count=864),
#  Row(word='January', count=864),
#  Row(word='maintain', count=864),
#  Row(word='18', count=864),
#  Row(word='2018', count=864),
#  Row(word='Code', count=864),
#  Row(word='Cost', count=864),
#  Row(word='patches', count=864),
#  Row(word='APIs.', count=864),
#  Row(word='StackOverflow', count=864),
#  Row(word='however', count=864),
#  Row(word='6', count=864),
#  Row(word='All', count=864),
#  Row(word='people', count=864),
#  Row(word='different', count=864),
#  Row(word='expect', count=864),
#  Row(word='Feature', count=864),
#  Row(word='2.3.x', count=864),
#  Row(word='cleanly', count=864),
#  Row(word='consider', count=864),
#  Row(word='voting', count=864),
#  Row(word='2.3.0', count=864),
#  Row(word='hard', count=864),
#  Row(word='never', count=864),
#  Row(word='guarantee', count=864),
#  Row(word='silently', count=864),
#  Row(word='higher', count=864),
#  Row(word='guidelines', count=864),
#  Row(word='QA', count=864),
#  Row(word='final', count=864),
#  Row(word='small', count=864),
#  Row(word='until', count=864),
#  Row(word='change', count=864),
#  Row(word='try', count=864),
#  Row(word='before', count=864),
#  Row(word='introduce', count=864),
#  Row(word='branch', count=864),
#  Row(word='Major', count=864),
#  Row(word='maintaining', count=864),
#  Row(word='many', count=864),
#  Row(word='Alpha', count=864),
#  Row(word='candidates', count=864),
#  Row(word='expected', count=864),
#  Row(word='fixes.', count=864),
#  Row(word='2.4.8', count=864),
#  Row(word='previous', count=850),
#  Row(word='Note', count=850),
#  Row(word='needed', count=850),
#  Row(word='(similar', count=850),
#  Row(word='compatible', count=850),
#  Row(word='between', count=850),
#  Row(word='without', count=850),
#  Row(word='relate', count=850),
#  Row(word='designed', count=850),
#  Row(word='our', count=850),
#  Row(word='work', count=850),
#  Row(word='listed', count=850),
#  Row(word='1', count=850),
#  Row(word='way', count=850),
#  Row(word='changes', count=850),
#  Row(word='libraries', count=850),
#  Row(word='compiler', count=850),
#  Row(word='know', count=850),
#  Row(word='number', count=850),
#  Row(word='mailing', count=850),
#  Row(word='Many', count=850),
#  Row(word='We', count=850),
#  Row(word='EC2', count=836),
#  Row(word='production', count=836),
#  Row(word='workloads', count=836),
#  Row(word='stream', count=836),
#  Row(word='using', count=836),
#  Row(word='deploy', count=836),
#  Row(word='data.', count=836),
#  Row(word='pipelines', count=836),
#  Row(word='software', count=836),
#  Row(word='provide', count=836),
#  Row(word='refer', count=836),
#  Row(word='You', count=836),
#  Row(word='built', count=836),
#  Row(word='computation', count=836),
#  Row(word="Foundation's", count=836),
#  Row(word='generation', count=836),
#  Row(word='sort', count=836),
#  Row(word='like', count=836),
#  Row(word='clusters', count=836),
#  Row(word='organizations', count=836),
#  Row(word='DStream', count=836),
#  Row(word='Software', count=836),
#  Row(word='express', count=836),
#  Row(word='Where', count=836),
#  Row(word='Does', count=836),
#  Row(word='parts', count=432),
#  Row(word='Updated', count=432),
#  Row(word='1.X.Y', count=432),
#  Row(word='documentation', count=432),
#  Row(word='instance', count=432),
#  Row(word='etc)', count=432),
#  Row(word='we’ll', count=432),
#  Row(word='debug', count=432),
#  Row(word='features.', count=432),
#  Row(word='question.', count=432),
#  Row(word='within', count=432),
#  Row(word='account', count=432),
#  Row(word='entirely', count=432),
#  Row(word='trying', count=432),
#  Row(word='2nd', count=432),
#  Row(word='algorithm', count=432),
#  Row(word='time.', count=432),
#  Row(word='reading', count=432),
#  Row(word='Starting', count=432),
#  Row(word='Behavior', count=432),
#  Row(word='deprecation', count=432),
#  Row(word='tests', count=432),
#  Row(word='deprecated', count=432),
#  Row(word='Focus', count=432),
#  Row(word='because', count=432),
#  Row(word='API.', count=432),
#  Row(word='sure', count=432),
#  Row(word='alternative', count=432),
#  Row(word='be:', count=432),
#  Row(word='must', count=432),
#  Row(word='stuck', count=432),
#  Row(word='November', count=432),
#  Row(word='occurs', count=432),
#  Row(word='stability', count=432),
#  Row(word='15th', count=432),
#  Row(word='2019', count=432),
#  Row(word='alternatives', count=432),
#  Row(word='ways', count=432),
#  Row(word='adding', count=432),
#  Row(word='remain', count=432),
#  Row(word='suggest', count=432),
#  Row(word='extent', count=432),
#  Row(word='maintenance', count=432),
#  Row(word='MAJOR', count=432),
#  Row(word='level', count=432),
#  Row(word='balance', count=432),
#  Row(word='non-trivial', count=432),
#  Row(word='becomes', count=432),
#  Row(word='Versioning', count=432),
#  Row(word='(very', count=432),
#  Row(word='way.', count=432),
#  Row(word='newer', count=432),
#  Row(word='recent', count=432),
#  Row(word='infeasible', count=432),
#  Row(word='too', count=432),
#  Row(word='Work', count=432),
#  Row(word='fix', count=432),
#  Row(word='bit', count=432),
#  Row(word='exacerbated', count=432),
#  Row(word='paths', count=432),
#  Row(word='3.4', count=432),
#  Row(word='become', count=432),
#  Row(word='according', count=432),
#  Row(word='confusing', count=432),
#  Row(word='31', count=432),
#  Row(word='strives', count=432),
#  Row(word='say', count=432),
#  Row(word='given', count=432),
#  Row(word='2.2.0', count=432),
#  Row(word='Event', count=432),
#  Row(word='had', count=432),
#  Row(word='upgraded', count=432),
#  Row(word='out', count=432),
#  Row(word='future', count=432),
#  Row(word='roughly', count=432),
#  Row(word='notice!)', count=432),
#  Row(word='specific', count=432),
#  Row(word='technically', count=432),
#  Row(word='course', count=432),
#  Row(word='Currently', count=432),
#  Row(word='semantic', count=432),
#  Row(word='today', count=432),
#  Row(word='Hence', count=432),
#  Row(word='fixes)', count=432),
#  Row(word='1.0.0', count=432),
#  Row(word='link', count=432),
#  Row(word='later', count=432),
#  Row(word='2.4.0', count=432),
#  Row(word='numbers', count=432),
#  Row(word='Community', count=432),
#  Row(word='“stable”', count=432),
#  Row(word='May', count=432),
#  Row(word='immediately', count=432),
#  Row(word='urgency', count=432),
#  Row(word='Considerations', count=432),
#  Row(word='Usage', count=432),
#  Row(word='Anytime', count=432),
#  Row(word='actively', count=432),
#  Row(word='versioned', count=432),
#  Row(word='evolve', count=432),
#  Row(word='blogs?', count=432),
#  Row(word='nature', count=432),
#  Row(word='removal', count=432),
#  Row(word='Link-level', count=432),
#  Row(word='semantics.', count=432),
#  Row(word='forever', count=432),
#  Row(word='done?', count=432),
#  Row(word='stable', count=432),
#  Row(word='depend', count=432),
#  Row(word='break?', count=432),
#  Row(word='Alternatives', count=432),
#  Row(word='versioning', count=432),
#  Row(word='more.', count=432),
#  Row(word='multi-module', count=432),
#  Row(word='deeply', count=432),
#  Row(word='passes', count=432),
#  Row(word='tested', count=432),
#  Row(word='completely', count=432),
#  Row(word='high.', count=432),
#  Row(word='deviations', count=432),
#  Row(word='Bad', count=432),
#  Row(word='periods', count=432),
#  Row(word='Breaking', count=432),
#  Row(word='factors', count=432),
#  Row(word='clearly', count=432),
#  Row(word='public', count=432),
#  Row(word='answers?', count=432),
#  Row(word='cadence', count=432),
#  Row(word='cut.', count=432),
#  Row(word='year', count=432),
#  Row(word='project.', count=432),
#  Row(word='estimate:', count=432),
#  Row(word='etc', count=432),
#  Row(word='whole', count=432),
#  Row(word='considerations', count=432),
#  Row(word='performing', count=432),
#  Row(word='resources', count=432),
#  Row(word='bugs', count=432),
#  Row(word='appear', count=432),
#  Row(word='announced', count=432),
#  Row(word='“Bad', count=432),
#  Row(word='Once', count=432),
#  Row(word='avoid', count=432),
#  Row(word='mean', count=432),
#  Row(word='hurt', count=432),
#  Row(word='(e.g', count=432),
#  Row(word='deprecated.', count=432),
#  Row(word='date', count=432),
#  Row(word='introduced', count=432),
#  Row(word='Avoid', count=432),
#  Row(word='“alpha”', count=432),
#  Row(word='see', count=432),
#  Row(word='merged.', count=432),
#  Row(word='choosing', count=432),
#  Row(word='high', count=432),
#  Row(word='abide', count=432),
#  Row(word='order', count=432),
#  Row(word='return', count=432),
#  Row(word='costs.', count=432),
#  Row(word='works', count=432),
#  Row(word='increasing', count=432),
#  Row(word='(RC)', count=432),
#  Row(word='plan', count=432),
#  Row(word='cognitive', count=432),
#  Row(word='clear', count=432),
#  Row(word='make', count=432),
#  Row(word='initially', count=432),
#  Row(word='minor', count=432),
#  Row(word='what', count=432),
#  Row(word='JIRA', count=432),
#  Row(word='“right”', count=432),
#  Row(word='Late', count=432),
#  Row(word='broken', count=432),
#  Row(word='places', count=432),
#  Row(word='questions', count=432),
#  Row(word='rewritten', count=432),
#  Row(word='obvious', count=432),
#  Row(word='isolated', count=432),
#  Row(word='Deprecation', count=432),
#  Row(word='Update', count=432),
#  Row(word='(“minor”)', count=432),
#  Row(word='changing', count=432),
#  Row(word='behavior', count=432),
#  Row(word='every', count=432),
#  Row(word='patch', count=432),
#  Row(word='Is', count=432),
#  Row(word='important', count=432),
#  Row(word='freeze', count=432),
#  Row(word='strive', count=432),
#  Row(word='eventually', count=432),
#  Row(word='“LTS”', count=432),
#  Row(word='Of', count=432),
#  Row(word='very', count=432),
#  Row(word='Think', count=432),
#  Row(word='docs', count=432),
#  Row(word='2021', count=432),
#  Row(word='guidelines.', count=432),
#  Row(word='programs?', count=432),
#  Row(word='question', count=432),
#  Row(word='significantly', count=432),
#  Row(word='fixed', count=432),
#  Row(word='severity:', count=432),
#  Row(word='User', count=432),
#  Row(word='something', count=432),
#  Row(word='usage', count=432),
#  Row(word='significant', count=432),
#  Row(word='[MAJOR].[FEATURE].[MAINTENANCE]', count=432),
#  Row(word='regular', count=432),
#  Row(word='warnings', count=432),
#  Row(word='MAINTENANCE', count=432),
#  Row(word='costly', count=432),
#  Row(word='Every', count=432),
#  Row(word='schedule.', count=432),
#  Row(word='releases.', count=432),
#  Row(word='Date', count=432),
#  Row(word='would', count=432),
#  Row(word='costs', count=432),
#  Row(word='understand', count=432),
#  Row(word='EOL', count=432),
#  Row(word='removing', count=432),
#  Row(word='Generally', count=432),
#  Row(word='Ubuntu).', count=432),
#  Row(word='Warnings', count=432),
#  Row(word='Documentation', count=432),
#  Row(word='merge', count=432),
#  Row(word='“best”', count=432),
#  Row(word='sites', count=432),
#  Row(word='runtime', count=432),
#  Row(word='compiles', count=432),
#  Row(word='thinking', count=432),
#  Row(word='Project', count=432),
#  Row(word='learn', count=432),
#  Row(word='FEATURE', count=432),
#  Row(word='blogs', count=432),
#  Row(word='2.4.x', count=432),
#  Row(word='improvements', count=432),
#  Row(word='plenty', count=432),
#  Row(word='linked', count=432),
#  Row(word='re-compiling', count=432),
#  Row(word='give', count=432),
#  Row(word='added', count=432),
#  Row(word='differences', count=432),
#  Row(word='An', count=432),
#  Row(word='lists?', count=432),
#  Row(word='exception?', count=432),
#  Row(word='When', count=432),
#  Row(word='external', count=432),
#  Row(word='undefined', count=432),
#  Row(word='additive', count=432),
#  Row(word='branches', count=432),
#  Row(word='Docs', count=432),
#  Row(word='exception', count=432),
#  Row(word='means', count=432),
#  Row(word='error?', count=432),
#  Row(word='keep', count=432),
#  Row(word='September', count=432),
#  Row(word='dependencies', count=432),
#  Row(word='address', count=432),
#  Row(word='almost', count=432),
#  Row(word='windows', count=432),
#  Row(word='frequently', count=432),
#  Row(word='linker', count=432),
#  Row(word='recommended', count=432),
#  Row(word='bunch', count=432),
#  Row(word='By', count=418),
#  Row(word='"Spark"', count=418),
#  Row(word='2016', count=418),
#  Row(word='scale', count=418),
#  Row(word='TB', count=418),
#  Row(word='summary.', count=418),
#  Row(word='name', count=418),
#  Row(word="RDD's", count=418),
#  Row(word='modified', count=418),
#  Row(word='special', count=418),
#  Row(word='discretized', count=418),
#  Row(word='show', count=418),
#  Row(word='help?', count=418),
#  Row(word='spilled', count=418),
#  Row(word='determined', count=418),
#  Row(word='page', count=418),
#  Row(word='Summit.', count=418),
#  Row(word='2014', count=418),
#  Row(word='commercial', count=418),
#  Row(word='use?', count=418),
#  Row(word='allowing', count=418),
#  Row(word='level.', count=418),
#  Row(word='Hive', count=418),
#  Row(word='URL', count=418),
#  Row(word='please', count=418),
#  Row(word='shown', count=418),
#  Row(word='plugins', count=418),
#  Row(word='node)', count=418),
#  Row(word='3X', count=418),
#  Row(word='sized', count=418),
#  Row(word='to?', count=418),
#  Row(word='cached', count=418),
#  Row(word='represents', count=418),
#  Row(word='terms', count=418),
#  Row(word='100', count=418),
#  Row(word='AMPLab', count=418),
#  Row(word='building', count=418),
#  Row(word='Cassandra', count=418),
#  Row(word='As', count=418),
#  Row(word='petabytes', count=418),
#  Row(word='cores)', count=418),
#  Row(word='What’s', count=418),
#  Row(word='third-party', count=418),
#  Row(word='Likewise', count=418),
#  Row(word='represented', count=418),
#  Row(word='locally', count=418),
#  Row(word='glad', count=418),
#  Row(word='Benchmark', count=418),
#  Row(word='Questions?', count=418),
#  Row(word='managers', count=418),
#  Row(word='path', count=418),
#  Row(word='allowed)', count=418),
#  Row(word='Who', count=418),
#  Row(word='master', count=418),
#  Row(word='learning.', count=418),
#  Row(word='wiki', count=418),
#  Row(word='updates', count=418),
#  Row(word='richer', count=418),
#  Row(word='easier', count=418),
#  Row(word='1000', count=418),
#  Row(word='ETL', count=418),
#  Row(word='white', count=418),
#  Row(word='PB', count=418),
#  Row(word='Foundation', count=418),
#  Row(word='aware', count=418),
#  Row(word='(names', count=418),
#  Row(word='HBase', count=418),
#  Row(word="you'd", count=418),
#  Row(word="We'll", count=418),
#  Row(word='migrate', count=418),
#  Row(word='C', count=418),
#  Row(word='See', count=418),
#  Row(word='cluster?', count=418),
#  Row(word='fly', count=418),
#  Row(word='local[N]', count=418),
#  Row(word='Do', count=418),
#  Row(word='recomputed', count=418),
#  Row(word='it’s', count=418),
#  Row(word='1/10th', count=418),
#  Row(word='difference', count=418),
#  Row(word='respect', count=418),
#  Row(word='queries', count=418),
#  Row(word='Some', count=418),
#  Row(word='Daytona', count=418),
#  Row(word='automatically', count=418),
#  Row(word='NFS', count=418),
#  Row(word='threads', count=418),
#  Row(word='note', count=418),
#  Row(word='PBs', count=418),
#  Row(word='current', count=418),
#  Row(word='find', count=418),
#  Row(word='production?', count=418),
#  Row(word='spill', count=418),
#  Row(word='N', count=418),
#  Row(word='high-resolution', count=418),
#  Row(word='strong', count=418),
#  Row(word='my', count=418),
#  Row(word='GraySort', count=418),
#  Row(word='Users', count=418),
#  Row(word='NumPy.', count=418),
#  Row(word='want.', count=418),
#  Row(word='trademarks', count=418),
#  Row(word='datasets', count=418),
#  Row(word='cluster.', count=418),
#  Row(word='surveys', count=418),
#  Row(word='There', count=418),
#  Row(word='tag', count=418),
#  Row(word='interactive', count=418),
#  Row(word='up', count=418),
#  Row(word='list', count=418),
#  Row(word='Yes', count=418),
#  Row(word='Powered', count=418),
#  Row(word='here', count=418),
#  Row(word='setup', count=418),
#  Row(word='operators', count=418),
#  Row(word='installed', count=418),
#  Row(word='high-level', count=418),
#  Row(word='SQL', count=418),
#  Row(word='contribute', count=418),
#  Row(word='static', count=418),
#  Row(word='(possibly', count=418),
#  Row(word='MapReduce)', count=418),
#  Row(word='call', count=418),
#  Row(word='FAQ', count=418),
#  Row(word='What', count=418),
#  Row(word='Streaming?', count=418),
#  Row(word='black', count=418),
#  Row(word='logo?', count=418),
#  Row(word='information.', count=418),
#  Row(word='apache-spark', count=418),
#  Row(word='services', count=418),
#  Row(word='winning', count=418),
#  Row(word='mounted', count=418),
#  Row(word='thousands', count=418),
#  Row(word='mode.', count=418),
#  Row(word='Spark™', count=418),
#  Row(word='logos.', count=418),
#  Row(word='Contributing', count=418),
#  Row(word='get', count=418),
#  Row(word='node', count=418),
#  Row(word='InputFormat', count=418),
#  Row(word='largest', count=418),
#  Row(word='filesystem', count=418),
#  Row(word='functionality', count=418),
#  Row(word='Can', count=418),
#  Row(word='standard', count=418),
#  ...]
